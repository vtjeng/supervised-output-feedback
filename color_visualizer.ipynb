# %%
# %matplotlib notebook

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
sns.palplot(sns.cubehelix_palette(20, start = 0, light = 1))
# Out:
# <img src="data:image/png;base64,...">

# %%
sns.palplot(sns.light_palette((25, 99, 50), input="husl", n_colors = 10))
# Out:
# <img src="data:image/png;base64,...">

# %%
np.round(sns.cubehelix_palette(64, light = 1), decimals = 4)[:,0:3]
# Out:
# array([[ 1.    ,  1.    ,  1.    ],
#        [ 0.9939,  0.9867,  0.981 ],
#        [ 0.9879,  0.9733,  0.9625],
#        [ 0.9803,  0.955 ,  0.9386],
#        [ 0.9748,  0.9411,  0.9213],
#        [ 0.9676,  0.9223,  0.899 ],
#        [ 0.9624,  0.908 ,  0.8829],
#        [ 0.9554,  0.8888,  0.8622],
#        [ 0.9503,  0.8743,  0.8474],
#        [ 0.9434,  0.8547,  0.8283],
#        [ 0.9383,  0.84  ,  0.8146],
#        [ 0.933 ,  0.8251,  0.8014],
#        [ 0.9259,  0.8053,  0.7846],
#        [ 0.9205,  0.7904,  0.7726],
#        [ 0.9131,  0.7704,  0.7572],
#        [ 0.9073,  0.7555,  0.7462],
#        [ 0.8993,  0.7355,  0.7323],
#        [ 0.8931,  0.7206,  0.7223],
#        [ 0.8845,  0.7008,  0.7096],
#        [ 0.8778,  0.6859,  0.7005],
#        [ 0.8684,  0.6663,  0.689 ],
#        [ 0.861 ,  0.6516,  0.6807],
#        [ 0.8534,  0.6371,  0.6728],
#        [ 0.8427,  0.6178,  0.6627],
#        [ 0.8343,  0.6035,  0.6554],
#        [ 0.8227,  0.5845,  0.646 ],
# ...
